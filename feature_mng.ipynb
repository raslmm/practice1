# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bitcoin.csv")

print("Dataset shape:", df.shape)
print(df.head())
# Out:
# Dataset shape: (5883, 7)
#          Date  Open      High       Low  Close  Volume PriceCategory
# 0  2010-01-01   0.3  0.303428  0.295510    0.3   715.8           Low
# 1  2010-01-02   0.3  0.304377  0.299459    0.3  2028.3           Low
# 2  2010-01-03   0.3  0.303736  0.295858    0.3   273.0           Low
# 3  2010-01-04   0.3  0.303406  0.298489    0.3  1452.0           Low
# 4  2010-01-05   0.3  0.302715  0.296330    0.3  1002.6           Low

# %%
if "Date" in df.columns:
    df = df.drop("Date", axis=1)

df = df.replace(',', '', regex=True)

for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')

df = df.dropna()

print("\nColumns:", df.columns)
# Out:
# Columns: Index(['Open', 'High', 'Low', 'Close', 'Volume', 'PriceCategory'], dtype='object')
# C:\Users\VICTUS 15\AppData\Local\Temp\ipykernel_9152\2315028416.py:7: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')

# %%
target_column = "Close"
X = df.drop("Close", axis=1)
y = df["Close"]
print(X, y)
# Out:
#          Open          High           Low       Volume PriceCategory
# 0         0.3      0.303428      0.295510        715.8           Low
# 1         0.3      0.304377      0.299459       2028.3           Low
# 2         0.3      0.303736      0.295858        273.0           Low
# 3         0.3      0.303406      0.298489       1452.0           Low
# 4         0.3      0.302715      0.296330       1002.6           Low
# ...       ...           ...           ...          ...           ...
# 5878  69000.0  70144.883975  68886.645749  343137000.0          High
# 5879  69000.0  70283.613241  67999.266453  344379000.0          High
# 5880  69000.0  69305.587376  67958.233281  524676000.0          High
# 5881  69000.0  69888.021412  68314.343334  117852000.0          High
# 5882  69000.0  69105.547292  67797.881438  623346000.0          High
#
# [5883 rows x 5 columns] 0           0.3
# 1           0.3
# 2           0.3
# 3           0.3
# 4           0.3
#          ...
# 5878    69000.0
# 5879    69000.0
# 5880    69000.0
# 5881    69000.0
# 5882    69000.0
# Name: Close, Length: 5883, dtype: float64

# %%
#encoding categorical
cat_cols = X.select_dtypes(include=['object']).columns
if len(cat_cols) > 0:
    print("Encoding:", list(cat_cols))
    X = pd.get_dummies(X, columns=cat_cols)
# Out:
# Encoding: ['PriceCategory']

# %%
X.to_csv('X_ready_for_modelling.csv', index=False)
y.to_csv('y_ready_for_modelling.csv', index=False)
